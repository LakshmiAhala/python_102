# %% [markdown]
# <a href="https://colab.research.google.com/github/LakshmiAhala/python_102/blob/main/Assign_16_GeneratorsIterators_102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Car class
class Car:
  def __init__(self, car_name, fuel_capacity, mileage, gas_level):
    self.carName = car_name
    self.fuelCapacity = fuel_capacity
    self.mileage = mileage
    self.gasLevel = gas_level


  def get_CarName():
    return self.carName

  def get_FuelCapacity():
    return self.fuelCapacity

  def get_Mileage():
    return self.mileage

  def get_GasLevel():
    return self.gasLevel

  def __repr__(self):
    car_details_str = ('\nName: ' + self.carName +
                     '\nFuel Capacity: ' + str(self.fuelCapacity) +
                     '\nMilage: ' + str(self.mileage) +
                     '\nCurrent Gas Level: ' + str(self.gasLevel))
    return car_details_str

# create a bunch of cars
print("\nCreating Mom's Car")
moms_car = Car('Volvo', 50, 20, 50)
print(moms_car)

# TODO: create dad's car
print("\nCreating Dad's Car")
dads_car = Car('Honda', 48, 23, 50)
print(dads_car)


# TODO: create an old car
print("\nCreating an old Car")
old_car = Car('Acura', 23, 10, 60)
print(old_car)

# TODO: create a new car
print("\nCreating a new Car")
new_car = Car('Tesla', 0, 30, 60)
print(new_car)
# Out:
# Creating Mom's Car
#
# Name: Volvo
# Fuel Capacity: 50
# Milage: 20
# Current Gas Level: 50
#
# Creating Dad's Car
#
# Name: Honda
# Fuel Capacity: 48
# Milage: 23
# Current Gas Level: 50
#
# Creating an old Car
#
# Name: Acura
# Fuel Capacity: 23
# Milage: 10
# Current Gas Level: 60
#
# Creating a new Car
#
# Name: Tesla
# Fuel Capacity: 0
# Milage: 30
# Current Gas Level: 60

# %%
#@title 'Cars Collection' (without generator functions)
class Cars_Collection:

    def __init__(self, some_collection = []):
        self.cars_list = some_collection

    def __repr__(self):
        for car in self.cars_list:
          print(car)

        return 'Cars in cars_list are printed'

    def add(self, some_car):
        self.cars_list.append(some_car)

    def remove(self, some_car):
        # find the car from the collection and remove it;
        # return true
        # if there is no car with that name, returnf alse
        if some_car in self.cars_list:
          self.cars_list.remove(some_car)

    def sort(self):
        # sort the cars in the collection by the mileage
        #self.cards_list.sort()
        pass

		# this method returns a car with highest mileage
    def get_car_with_highest_mileage(self):
       pass


# all testing happens here
car1 = Car('Honda', 50, 24, 50)
car2 = Car('Kia', 70, 20, 50)

# printing the cars collection through __repr__ or __str__ method
cars_list = [moms_car, dads_car, old_car, new_car, car1, car2]
car_dealer_collection = Cars_Collection(cars_list)
print(car_dealer_collection)
# Out:
# Name: Volvo
# Fuel Capacity: 50
# Milage: 20
# Current Gas Level: 50
#
# Name: Honda
# Fuel Capacity: 48
# Milage: 23
# Current Gas Level: 50
#
# Name: Acura
# Fuel Capacity: 23
# Milage: 10
# Current Gas Level: 60
#
# Name: Tesla
# Fuel Capacity: 0
# Milage: 30
# Current Gas Level: 60
#
# Name: Honda
# Fuel Capacity: 50
# Milage: 24
# Current Gas Level: 50
#
# Name: Kia
# Fuel Capacity: 70
# Milage: 20
# Current Gas Level: 50
# Cars in cars_list are printed

# %%
#@title 'Cars Collection' class as a generator (with iter and next magic methods)
class Cars_Collection:

    def __init__(self, some_collection = []):
        self.cars_list = some_collection
        self.pos = 0

    # def __repr__(self):
    #     for car in self.cars_list:
    #       print(car)

    #     return 'Cars in cars_list are printed'

    def add(self, some_car):
        self.cars_list.append(some_car)

    def remove(self, some_car):
        # find the car from the collection and remove it;
        # return true
        # if there is no car with that name, returnf alse
        if some_car in self.cars_list:
          self.cars_list.remove(some_car)

    def sort(self):
        # sort the cars in the collection by the mileage
        #self.cards_list.sort()
        pass

		# this method returns a car with highest mileage
    def get_car_with_highest_mileage(self):
       pass

    def __iter__(self):
        print("Cars Collection iterator")
        return self

    def __next__(self):
        print("iterating over the cars collection")
        if self.pos >= len(self.cars_list):
            raise StopIteration
        car_to_be_returned = self.cars_list[self.pos]
        self.pos += 1
        return car_to_be_returned


# all testing happens here
car1 = Car('Honda', 50, 24, 50)
car2 = Car('Kia', 70, 20, 50)

cars_list = [moms_car, dads_car, old_car, new_car, car1, car2]
# car_dealer_collection = Cars_Collection(cars_list)
# print(car_dealer_collection)

# Create a brand new cars collection
cars_collection_2 = Cars_Collection(cars_list)

# printing the cars collection by making the cars_collection as a generator
for elem in cars_collection_2:
  print(elem)
# Out:
# Cars Collection iterator
# iterating over the cars collection
#
# Name: Volvo
# Fuel Capacity: 50
# Milage: 20
# Current Gas Level: 50
# iterating over the cars collection
#
# Name: Honda
# Fuel Capacity: 48
# Milage: 23
# Current Gas Level: 50
# iterating over the cars collection
#
# Name: Acura
# Fuel Capacity: 23
# Milage: 10
# Current Gas Level: 60
# iterating over the cars collection
#
# Name: Tesla
# Fuel Capacity: 0
# Milage: 30
# Current Gas Level: 60
# iterating over the cars collection
#
# Name: Honda
# Fuel Capacity: 50
# Milage: 24
# Current Gas Level: 50
# iterating over the cars collection
#
# Name: Kia
# Fuel Capacity: 70
# Milage: 20
# Current Gas Level: 50
# iterating over the cars collection

# %%
#@title Book class
class Book:
  def __init__(self, book, author):
    self.book_name = book
    self.author_name = author

  def get_BookName():
    return self.book_name

  def get_AuthorName():
    return self.author_name

  def __repr__(self):
    book_details_str = ('Name: ' + self.book_name +
                       '\nAuthor: ', self.author_name)
    return book_details_str

  def __str__(self):
    book_str = ('Name: ' + self.book_name +
              '\nAuthor: ' + self.author_name)
    return book_str

# Creating a bunch of Books

# Creating hp_book
print("\nCreating hp_book")
hp_book = Book("Harry Potter and the Sorcerer's Stone", "JK Rowling")
print(hp_book)

# Creating vp_book
print("\nCreating vp_book")
vp_book = Book('Veyi Padagalu', 'Viswanatha Satyanarayana')
print(vp_book)

# Creating tkm_book
print("\nCreating tkm_book")
tkm_book = Book('To Kill a Mockingbird', 'Harper Lee')
print(tkm_book)
# Out:
# Creating hp_book
# Name: Harry Potter and the Sorcerer's Stone
# Author: JK Rowling
#
# Creating vp_book
# Name: Veyi Padagalu
# Author: Viswanatha Satyanarayana
#
# Creating tkm_book
# Name: To Kill a Mockingbird
# Author: Harper Lee

# %%
#@title 'Books Collection' (without generator functions)
class Books_Collection:

    def __init__(self, some_collection = []):
        self.books_list = some_collection

    def __repr__(self):
        for book in self.books_list:
          print(book)
        return 'Books in books_list are printed'

    def add(self, some_book):
        self.cars_list.append(some_book)

    def remove(self, some_car):
        # find the car from the collection and remove it;
        # return true
        # if there is no car with that name, returnf alse
        if some_book in self.books_list:
          self.books_list.remove(some_book)

    def sort(self):
        # sort the cars in the collection by the mileage
        #self.cards_list.sort()
        pass

		# this method returns a car with highest mileage
    def get_car_with_highest_mileage(self):
       pass


# all testing happens here
#  = Car('Honda', 50, 24, 50)
# car2 = Car('Kia', 70, 20, 50)

# printing the cars collection through __repr__ or __str__ method
books_list = [hp_book, vp_book, tkm_book]
book_collection = Books_Collection(books_list)
print(book_collection)
# Out:
# Name: Harry Potter and the Sorcerer's Stone
# Author: JK Rowling
# Name: Veyi Padagalu
# Author: Viswanatha Satyanarayana
# Name: To Kill a Mockingbird
# Author: Harper Lee
# Books in books_list are printed

# %%
#@title 'Books Collection' class as a generator (with iter and next magic methods)
class Books_Collection:

    def __init__(self, some_collection = []):
        self.books_list = some_collection
        self.pos = 0

    # def __repr__(self):
    #     for car in self.cars_list:
    #       print(car)

    #     return 'Cars in cars_list are printed'

    def add(self, some_book):
        self.books_list.append(some_book)

    def remove(self, some_book):
        # find the car from the collection and remove it;
        # return true
        # if there is no car with that name, returnf alse
        if some_book in self.books_list:
          self.books_list.remove(some_book)

    def sort(self):
        # sort the cars in the collection by the mileage
        #self.cards_list.sort()
        pass

		# this method returns a car with highest mileage
    def get_car_with_highest_mileage(self):
       pass

    def __iter__(self):
        print("Books Collection iterator")
        return self

    def __next__(self):
        print("\nIterating over the books collection")
        if self.pos >= len(self.books_list):
            raise StopIteration
        book_to_be_returned = self.books_list[self.pos]
        self.pos += 1
        return book_to_be_returned


# # all testing happens here
# car1 = Car('Honda', 50, 24, 50)
# car2 = Car('Kia', 70, 20, 50)

books_list = [hp_book, vp_book, tkm_book]
# car_dealer_collection = Cars_Collection(cars_list)
# print(car_dealer_collection)

# Create a brand new cars collection
books_collection_dup = Books_Collection(books_list)

# printing the cars collection by making the cars_collection as a generator
for elem in books_collection_dup:
  print(elem)
# Out:
# Books Collection iterator
#
# Iterating over the books collection
# Name: Harry Potter and the Sorcerer's Stone
# Author: JK Rowling
#
# Iterating over the books collection
# Name: Veyi Padagalu
# Author: Viswanatha Satyanarayana
#
# Iterating over the books collection
# Name: To Kill a Mockingbird
# Author: Harper Lee
#
# Iterating over the books collection
